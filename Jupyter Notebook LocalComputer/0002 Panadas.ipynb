# %%
#!pip install pandas

# %%
data = {
    'Empid': [101,102,103,104,105,106,107,108,109],
    'Empname': ['Ram','Shyam','Mohan' , 'Rohan','Anu','Riya','Simran','Nameera' ,'Mohit','Bhavna '],
    'Empsalary':[42121,43232,21331,43532,83637,37212,18173,73536,21341,42313]
}

# %%
#•	Pandas is used to Extract and  Transform  the data 
#•	Loading data from a source like csv , xls, parqueet  , json and database etc
#•	Data should be series(1 D)  or DataFrame(Tabular Format)

# %%
import pandas as pd
import numpy as np
