# %%
#                                                 🟢 Beginner (20 Questions)
# Show first 10 rows.
# Show last 7 rows.
# Dataset shape.
# Number of rows.
# Number of columns.
# Display all column names.
# Display datatypes.
# Display statistical summary.
# Display only Name column.
# Display Name and Salary.
# Find average salary.
# Find highest salary.
# Find lowest salary.
# Find total salary.
# Count missing values.
# Total missing values.
# Replace missing Name.
# Fill Salary with mean.
# Fill Age with mean.
# Fill Experience with mean.

# %%
import pandas as pd
import numpy as np

data = {
    "EmpID":[101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120],
    "Name":["Ram","Shyam","Mohan","Rohan","Anu","Riya","Simran","Neha","Mohit","Bhavna",
            "Karan","Amit",np.nan,"Sneha","Pooja","Vikas","Nitin","Asha","Rahul","Priya"],

    "Department":["IT","HR","IT","Sales","Finance","HR","IT","Finance","Sales","IT",
                  "HR","Finance","IT","Sales","HR","IT","Finance","HR","Sales","IT"],

    "City":["Delhi","Noida","Delhi","Mumbai","Pune","Delhi","Noida","Pune","Mumbai",
            "Delhi","Noida","Pune","Delhi","Mumbai","Noida","Delhi","Pune","Delhi","Mumbai","Noida"],

    "Salary":[45000,52000,np.nan,38000,70000,48000,55000,np.nan,
              41000,62000,47000,65000,53000,39000,np.nan,80000,58000,51000,43000,60000],

    "Age":[24,28,30,np.nan,40,27,26,31,29,38,25,36,np.nan,33,27,41,34,26,32,np.nan],

    "Experience":[2,5,7,3,15,4,3,np.nan,6,12,2,10,5,8,np.nan,18,9,3,7,11]
}

df = pd.DataFrame(data)

# %%
# Show first 10 rows.
df.head(10)
# Out:
#    EmpID    Name Department    City   Salary   Age  Experience
# 0    101     Ram         IT   Delhi  45000.0  24.0         2.0
# 1    102   Shyam         HR   Noida  52000.0  28.0         5.0
# 2    103   Mohan         IT   Delhi      NaN  30.0         7.0
# 3    104   Rohan      Sales  Mumbai  38000.0   NaN         3.0
# 4    105     Anu    Finance    Pune  70000.0  40.0        15.0
# 5    106    Riya         HR   Delhi  48000.0  27.0         4.0
# 6    107  Simran         IT   Noida  55000.0  26.0         3.0
# 7    108    Neha    Finance    Pune      NaN  31.0         NaN
# 8    109   Mohit      Sales  Mumbai  41000.0  29.0         6.0
# 9    110  Bhavna         IT   Delhi  62000.0  38.0        12.0

# %%
# Show last 7 rows.
df.tail(7)
# Out:
#     EmpID   Name Department    City   Salary   Age  Experience
# 13    114  Sneha      Sales  Mumbai  39000.0  33.0         8.0
# 14    115  Pooja         HR   Noida      NaN  27.0         NaN
# 15    116  Vikas         IT   Delhi  80000.0  41.0        18.0
# 16    117  Nitin    Finance    Pune  58000.0  34.0         9.0
# 17    118   Asha         HR   Delhi  51000.0  26.0         3.0
# 18    119  Rahul      Sales  Mumbai  43000.0  32.0         7.0
# 19    120  Priya         IT   Noida  60000.0   NaN        11.0

# %%
# Dataset shape.
df.shape
# Out:
# (20, 7)

# %%
# Number of rows.
df.shape[0]
# Out:
# 20

# %%
#Number of columns.
df.shape[1]
# Out:
# 7

# %%
#Display all column names.
df.columns
# Out:
# Index(['EmpID', 'Name', 'Department', 'City', 'Salary', 'Age', 'Experience'], dtype='str')

# %%
#Display datatypes.
df.dtypes
# Out:
# EmpID           int64
# Name              str
# Department        str
# City              str
# Salary        float64
# Age           float64
# Experience    float64
# dtype: object

# %%
#Display statistical summary.
df.describe()
# Out:
#            EmpID        Salary        Age  Experience
# count   20.00000     17.000000  17.000000   18.000000
# mean   110.50000  53352.941176  31.000000    7.222222
# std      5.91608  11494.244084   5.303301    4.570436
# min    101.00000  38000.000000  24.000000    2.000000
# 25%    105.75000  45000.000000  27.000000    3.250000
# 50%    110.50000  52000.000000  30.000000    6.500000
# 75%    115.25000  60000.000000  34.000000    9.750000
# max    120.00000  80000.000000  41.000000   18.000000

# %%
#Display only Name column.
df['Name']
# Out:
# 0        Ram
# 1      Shyam
# 2      Mohan
# 3      Rohan
# 4        Anu
# 5       Riya
# 6     Simran
# 7       Neha
# 8      Mohit
# 9     Bhavna
# 10     Karan
# 11      Amit
# 12       NaN
# 13     Sneha
# 14     Pooja
# 15     Vikas
# 16     Nitin
# 17      Asha
# 18     Rahul
# 19     Priya
# Name: Name, dtype: str

# %%
#Display Name and Salary.
df[['Name' ,  'Salary']]
# Out:
#       Name   Salary
# 0      Ram  45000.0
# 1    Shyam  52000.0
# 2    Mohan      NaN
# 3    Rohan  38000.0
# 4      Anu  70000.0
# 5     Riya  48000.0
# 6   Simran  55000.0
# 7     Neha      NaN
# 8    Mohit  41000.0
# 9   Bhavna  62000.0
# 10   Karan  47000.0
# 11    Amit  65000.0
# 12     NaN  53000.0
# 13   Sneha  39000.0
# 14   Pooja      NaN
# 15   Vikas  80000.0
# 16   Nitin  58000.0
# 17    Asha  51000.0
# 18   Rahul  43000.0
# 19   Priya  60000.0

# %%
#Find average salary.
df.Salary.mean()
# Out:
# np.float64(53352.94117647059)

# %%
#Find highest salary.
df.Salary.max()
# Out:
# np.float64(80000.0)

# %%
#Find lowest salary
df.Salary.min()
# Out:
# np.float64(38000.0)

# %%
#Find total salary.
df.Salary.sum()
# Out:
# np.float64(907000.0)

# %%
#Count missing values.
df.isnull().sum()
# Out:
# EmpID         0
# Name          1
# Department    0
# City          0
# Salary        3
# Age           3
# Experience    2
# dtype: int64

# %%
#Total missing values.
df.isnull().sum().sum()
# Out:
# np.int64(9)

# %%
#Replace missing Name.
df.Name.fillna('Unknown')
# Out:
# 0         Ram
# 1       Shyam
# 2       Mohan
# 3       Rohan
# 4         Anu
# 5        Riya
# 6      Simran
# 7        Neha
# 8       Mohit
# 9      Bhavna
# 10      Karan
# 11       Amit
# 12    Unknown
# 13      Sneha
# 14      Pooja
# 15      Vikas
# 16      Nitin
# 17       Asha
# 18      Rahul
# 19      Priya
# Name: Name, dtype: str

# %%
#Fill Salary with mean.
df.Salary.fillna(round(df.Salary.mean(),2))
# Out:
# 0     45000.00
# 1     52000.00
# 2     53352.94
# 3     38000.00
# 4     70000.00
# 5     48000.00
# 6     55000.00
# 7     53352.94
# 8     41000.00
# 9     62000.00
# 10    47000.00
# 11    65000.00
# 12    53000.00
# 13    39000.00
# 14    53352.94
# 15    80000.00
# 16    58000.00
# 17    51000.00
# 18    43000.00
# 19    60000.00
# Name: Salary, dtype: float64

# %%
#Fill Age with mean.
df.Age.fillna(df.Age.mean())
# Out:
# 0     24.0
# 1     28.0
# 2     30.0
# 3     31.0
# 4     40.0
# 5     27.0
# 6     26.0
# 7     31.0
# 8     29.0
# 9     38.0
# 10    25.0
# 11    36.0
# 12    31.0
# 13    33.0
# 14    27.0
# 15    41.0
# 16    34.0
# 17    26.0
# 18    32.0
# 19    31.0
# Name: Age, dtype: float64

# %%
#Fill Experience with mean.
df.Experience.fillna(df.Experience.mean().round(2))
# Out:
# 0      2.00
# 1      5.00
# 2      7.00
# 3      3.00
# 4     15.00
# 5      4.00
# 6      3.00
# 7      7.22
# 8      6.00
# 9     12.00
# 10     2.00
# 11    10.00
# 12     5.00
# 13     8.00
# 14     7.22
# 15    18.00
# 16     9.00
# 17     3.00
# 18     7.00
# 19    11.00
# Name: Experience, dtype: float64

# %%
# 🟡 Intermediate (25 Questions)
# Rename Salary to MonthlySalary.
# Rename Department to Dept.
# Show only IT employees.
# Show HR employees.
# Employees whose salary > 50000.
# Salary between 45000 and 70000.
# Age > 30.
# Experience > 5.
# Employees from Delhi.
# Employees from Delhi and IT.
# Employees from Mumbai or Pune.
# Count unique cities.
# Display all unique departments.
# Count employees department-wise.
# Count employees city-wise.
# Most common city.
# Most common department.
# Sort salary ascending.
# Sort salary descending.
# Sort City then Salary descending.
# Drop duplicate cities.
# Use isin() to display Delhi, Noida and Pune employees.
# Display numeric columns only.
# Display string columns only.
# Convert first 3 letters of Name using lambda.

# %%
# Rename Salary to MonthlySalary.
df.rename(columns= {'Salary':'MonthlySalary'})
# Out:
#     EmpID    Name Department    City  MonthlySalary   Age  Experience
# 0     101     Ram         IT   Delhi        45000.0  24.0         2.0
# 1     102   Shyam         HR   Noida        52000.0  28.0         5.0
# 2     103   Mohan         IT   Delhi            NaN  30.0         7.0
# 3     104   Rohan      Sales  Mumbai        38000.0   NaN         3.0
# 4     105     Anu    Finance    Pune        70000.0  40.0        15.0
# 5     106    Riya         HR   Delhi        48000.0  27.0         4.0
# 6     107  Simran         IT   Noida        55000.0  26.0         3.0
# 7     108    Neha    Finance    Pune            NaN  31.0         NaN
# 8     109   Mohit      Sales  Mumbai        41000.0  29.0         6.0
# 9     110  Bhavna         IT   Delhi        62000.0  38.0        12.0
# 10    111   Karan         HR   Noida        47000.0  25.0         2.0
# 11    112    Amit    Finance    Pune        65000.0  36.0        10.0
# ...

# %%
#Rename Department to Dept.
df.rename(columns= {'Department' : 'Dept'})
# Out:
#     EmpID    Name     Dept    City   Salary   Age  Experience
# 0     101     Ram       IT   Delhi  45000.0  24.0         2.0
# 1     102   Shyam       HR   Noida  52000.0  28.0         5.0
# 2     103   Mohan       IT   Delhi      NaN  30.0         7.0
# 3     104   Rohan    Sales  Mumbai  38000.0   NaN         3.0
# 4     105     Anu  Finance    Pune  70000.0  40.0        15.0
# 5     106    Riya       HR   Delhi  48000.0  27.0         4.0
# 6     107  Simran       IT   Noida  55000.0  26.0         3.0
# 7     108    Neha  Finance    Pune      NaN  31.0         NaN
# 8     109   Mohit    Sales  Mumbai  41000.0  29.0         6.0
# 9     110  Bhavna       IT   Delhi  62000.0  38.0        12.0
# 10    111   Karan       HR   Noida  47000.0  25.0         2.0
# 11    112    Amit  Finance    Pune  65000.0  36.0        10.0
# 12    113     NaN       IT   Delhi  53000.0   NaN         5.0
# 13    114   Sneha    Sales  Mumbai  39000.0  33.0         8.0
# ...

# %%
#Show only IT employees.
df[df['Department']=='IT']
# Out:
#     EmpID    Name Department   City   Salary   Age  Experience
# 0     101     Ram         IT  Delhi  45000.0  24.0         2.0
# 2     103   Mohan         IT  Delhi      NaN  30.0         7.0
# 6     107  Simran         IT  Noida  55000.0  26.0         3.0
# 9     110  Bhavna         IT  Delhi  62000.0  38.0        12.0
# 12    113     NaN         IT  Delhi  53000.0   NaN         5.0
# 15    116   Vikas         IT  Delhi  80000.0  41.0        18.0
# 19    120   Priya         IT  Noida  60000.0   NaN        11.0

# %%
#Show HR employees.
df[df.Department == 'HR']
# Out:
#     EmpID   Name Department   City   Salary   Age  Experience
# 1     102  Shyam         HR  Noida  52000.0  28.0         5.0
# 5     106   Riya         HR  Delhi  48000.0  27.0         4.0
# 10    111  Karan         HR  Noida  47000.0  25.0         2.0
# 14    115  Pooja         HR  Noida      NaN  27.0         NaN
# 17    118   Asha         HR  Delhi  51000.0  26.0         3.0

# %%
#Employees whose salary > 50000.
df[df.Salary>50000]
# Out:
#     EmpID    Name Department   City   Salary   Age  Experience
# 1     102   Shyam         HR  Noida  52000.0  28.0         5.0
# 4     105     Anu    Finance   Pune  70000.0  40.0        15.0
# 6     107  Simran         IT  Noida  55000.0  26.0         3.0
# 9     110  Bhavna         IT  Delhi  62000.0  38.0        12.0
# 11    112    Amit    Finance   Pune  65000.0  36.0        10.0
# 12    113     NaN         IT  Delhi  53000.0   NaN         5.0
# 15    116   Vikas         IT  Delhi  80000.0  41.0        18.0
# 16    117   Nitin    Finance   Pune  58000.0  34.0         9.0
# 17    118    Asha         HR  Delhi  51000.0  26.0         3.0
# 19    120   Priya         IT  Noida  60000.0   NaN        11.0

# %%
#Salary between 45000 and 70000.
mask1 = df.Salary>45000 
mask2 = df.Salary<70000
df[mask1 & mask2]
# Out:
#     EmpID    Name Department   City   Salary   Age  Experience
# 1     102   Shyam         HR  Noida  52000.0  28.0         5.0
# 5     106    Riya         HR  Delhi  48000.0  27.0         4.0
# 6     107  Simran         IT  Noida  55000.0  26.0         3.0
# 9     110  Bhavna         IT  Delhi  62000.0  38.0        12.0
# 10    111   Karan         HR  Noida  47000.0  25.0         2.0
# 11    112    Amit    Finance   Pune  65000.0  36.0        10.0
# 12    113     NaN         IT  Delhi  53000.0   NaN         5.0
# 16    117   Nitin    Finance   Pune  58000.0  34.0         9.0
# 17    118    Asha         HR  Delhi  51000.0  26.0         3.0
# 19    120   Priya         IT  Noida  60000.0   NaN        11.0

# %%
#Age > 30.
df[df.Age>30]
# Out:
#     EmpID    Name Department    City   Salary   Age  Experience
# 4     105     Anu    Finance    Pune  70000.0  40.0        15.0
# 7     108    Neha    Finance    Pune      NaN  31.0         NaN
# 9     110  Bhavna         IT   Delhi  62000.0  38.0        12.0
# 11    112    Amit    Finance    Pune  65000.0  36.0        10.0
# 13    114   Sneha      Sales  Mumbai  39000.0  33.0         8.0
# 15    116   Vikas         IT   Delhi  80000.0  41.0        18.0
# 16    117   Nitin    Finance    Pune  58000.0  34.0         9.0
# 18    119   Rahul      Sales  Mumbai  43000.0  32.0         7.0

# %%
#Experience > 5.
df[df.Experience > 5 ]
# Out:
#     EmpID    Name Department    City   Salary   Age  Experience
# 2     103   Mohan         IT   Delhi      NaN  30.0         7.0
# 4     105     Anu    Finance    Pune  70000.0  40.0        15.0
# 8     109   Mohit      Sales  Mumbai  41000.0  29.0         6.0
# 9     110  Bhavna         IT   Delhi  62000.0  38.0        12.0
# 11    112    Amit    Finance    Pune  65000.0  36.0        10.0
# 13    114   Sneha      Sales  Mumbai  39000.0  33.0         8.0
# 15    116   Vikas         IT   Delhi  80000.0  41.0        18.0
# 16    117   Nitin    Finance    Pune  58000.0  34.0         9.0
# 18    119   Rahul      Sales  Mumbai  43000.0  32.0         7.0
# 19    120   Priya         IT   Noida  60000.0   NaN        11.0

# %%
#Employees from Delhi
df[df['City'] == 'Delhi']
# Out:
#     EmpID    Name Department   City   Salary   Age  Experience
# 0     101     Ram         IT  Delhi  45000.0  24.0         2.0
# 2     103   Mohan         IT  Delhi      NaN  30.0         7.0
# 5     106    Riya         HR  Delhi  48000.0  27.0         4.0
# 9     110  Bhavna         IT  Delhi  62000.0  38.0        12.0
# 12    113     NaN         IT  Delhi  53000.0   NaN         5.0
# 15    116   Vikas         IT  Delhi  80000.0  41.0        18.0
# 17    118    Asha         HR  Delhi  51000.0  26.0         3.0

# %%
#Employees from Delhi and IT.
mask1 = df.City == 'Delhi'
mask2 = df.Department=='IT'
df[mask1 & mask2]
# Out:
#     EmpID    Name Department   City   Salary   Age  Experience
# 0     101     Ram         IT  Delhi  45000.0  24.0         2.0
# 2     103   Mohan         IT  Delhi      NaN  30.0         7.0
# 9     110  Bhavna         IT  Delhi  62000.0  38.0        12.0
# 12    113     NaN         IT  Delhi  53000.0   NaN         5.0
# 15    116   Vikas         IT  Delhi  80000.0  41.0        18.0

# %%
#Employees from Mumbai or Pune.
mask1 = df.City == 'Mumbai'
mask2 = df.City == 'Pune'
df[mask1 | mask2]
# Out:
#     EmpID   Name Department    City   Salary   Age  Experience
# 3     104  Rohan      Sales  Mumbai  38000.0   NaN         3.0
# 4     105    Anu    Finance    Pune  70000.0  40.0        15.0
# 7     108   Neha    Finance    Pune      NaN  31.0         NaN
# 8     109  Mohit      Sales  Mumbai  41000.0  29.0         6.0
# 11    112   Amit    Finance    Pune  65000.0  36.0        10.0
# 13    114  Sneha      Sales  Mumbai  39000.0  33.0         8.0
# 16    117  Nitin    Finance    Pune  58000.0  34.0         9.0
# 18    119  Rahul      Sales  Mumbai  43000.0  32.0         7.0

# %%
#Count unique cities.
df.City.unique()
# Out:
# <StringArray>
# ['Delhi', 'Noida', 'Mumbai', 'Pune']
# Length: 4, dtype: str

# %%
#Display all unique departments.
df.Department.unique()
# Out:
# <StringArray>
# ['IT', 'HR', 'Sales', 'Finance']
# Length: 4, dtype: str

# %%
#Count employees department-wise.
df.Department.value_counts()
# Out:
# Department
# IT         7
# HR         5
# Sales      4
# Finance    4
# Name: count, dtype: int64

# %%
#Count employees city-wise.
df.City.value_counts()
# Out:
# City
# Delhi     7
# Noida     5
# Mumbai    4
# Pune      4
# Name: count, dtype: int64

# %%
#Most common city.
df.City.mode()[0]
# Out:
# 'Delhi'

# %%
#Most common department.
df['Department'].mode()[0]
# Out:
# 'IT'

# %%
#Sort salary ascending.
df.Salary.sort_values()
df.sort_values(by = 'Salary')
# Out:
#     EmpID    Name Department    City   Salary   Age  Experience
# 3     104   Rohan      Sales  Mumbai  38000.0   NaN         3.0
# 13    114   Sneha      Sales  Mumbai  39000.0  33.0         8.0
# 8     109   Mohit      Sales  Mumbai  41000.0  29.0         6.0
# 18    119   Rahul      Sales  Mumbai  43000.0  32.0         7.0
# 0     101     Ram         IT   Delhi  45000.0  24.0         2.0
# 10    111   Karan         HR   Noida  47000.0  25.0         2.0
# 5     106    Riya         HR   Delhi  48000.0  27.0         4.0
# 17    118    Asha         HR   Delhi  51000.0  26.0         3.0
# 1     102   Shyam         HR   Noida  52000.0  28.0         5.0
# 12    113     NaN         IT   Delhi  53000.0   NaN         5.0
# 6     107  Simran         IT   Noida  55000.0  26.0         3.0
# 16    117   Nitin    Finance    Pune  58000.0  34.0         9.0
# 19    120   Priya         IT   Noida  60000.0   NaN        11.0
# 9     110  Bhavna         IT   Delhi  62000.0  38.0        12.0
# ...

# %%
#Sort salary descending.
df.sort_values(by = 'Salary' , ascending = False)
# Out:
#     EmpID    Name Department    City   Salary   Age  Experience
# 15    116   Vikas         IT   Delhi  80000.0  41.0        18.0
# 4     105     Anu    Finance    Pune  70000.0  40.0        15.0
# 11    112    Amit    Finance    Pune  65000.0  36.0        10.0
# 9     110  Bhavna         IT   Delhi  62000.0  38.0        12.0
# 19    120   Priya         IT   Noida  60000.0   NaN        11.0
# 16    117   Nitin    Finance    Pune  58000.0  34.0         9.0
# 6     107  Simran         IT   Noida  55000.0  26.0         3.0
# 12    113     NaN         IT   Delhi  53000.0   NaN         5.0
# 1     102   Shyam         HR   Noida  52000.0  28.0         5.0
# 17    118    Asha         HR   Delhi  51000.0  26.0         3.0
# 5     106    Riya         HR   Delhi  48000.0  27.0         4.0
# 10    111   Karan         HR   Noida  47000.0  25.0         2.0
# 0     101     Ram         IT   Delhi  45000.0  24.0         2.0
# 18    119   Rahul      Sales  Mumbai  43000.0  32.0         7.0
# ...

# %%
#Sort City then Salary descending.
df.sort_values(by = ['City' , 'Salary'] , ascending = [False , True])
# Out:
#     EmpID     Name Department    City   Salary   Age  Experience
# 16    117    Nitin    Finance    Pune  58000.0  34.0         9.0
# 11    112     Amit    Finance    Pune  65000.0  36.0        10.0
# 4     105      Anu    Finance    Pune  70000.0  40.0        15.0
# 7     108     Neha    Finance    Pune      NaN  31.0         NaN
# 10    111    Karan         HR   Noida  47000.0  25.0         2.0
# 1     102    Shyam         HR   Noida  52000.0  28.0         5.0
# 6     107   Simran         IT   Noida  55000.0  26.0         3.0
# 19    120    Priya         IT   Noida  60000.0   NaN        11.0
# 14    115    Pooja         HR   Noida      NaN  27.0         NaN
# 3     104    Rohan      Sales  Mumbai  38000.0   NaN         3.0
# 13    114    Sneha      Sales  Mumbai  39000.0  33.0         8.0
# 8     109    Mohit      Sales  Mumbai  41000.0  29.0         6.0
# 18    119    Rahul      Sales  Mumbai  43000.0  32.0         7.0
# ...

# %%
#Drop duplicate cities.
df.drop_duplicates(subset = ['City'])
# Out:
#    EmpID   Name Department    City   Salary   Age  Experience
# 0    101    Ram         IT   Delhi  45000.0  24.0         2.0
# 1    102  Shyam         HR   Noida  52000.0  28.0         5.0
# 3    104  Rohan      Sales  Mumbai  38000.0   NaN         3.0
# 4    105    Anu    Finance    Pune  70000.0  40.0        15.0

# %%
#Use isin() to display Delhi, Noida and Pune employees.
mask1 = df.City.isin(['Delhi' ])
mask2 = df.City.isin(['Noida' ])
mask3 = df.City.isin(['Pune' ])
df[mask1 | mask2 | mask3]
# Out:
#     EmpID    Name Department   City   Salary   Age  Experience
# 0     101     Ram         IT  Delhi  45000.0  24.0         2.0
# 1     102   Shyam         HR  Noida  52000.0  28.0         5.0
# 2     103   Mohan         IT  Delhi      NaN  30.0         7.0
# 4     105     Anu    Finance   Pune  70000.0  40.0        15.0
# 5     106    Riya         HR  Delhi  48000.0  27.0         4.0
# 6     107  Simran         IT  Noida  55000.0  26.0         3.0
# 7     108    Neha    Finance   Pune      NaN  31.0         NaN
# 9     110  Bhavna         IT  Delhi  62000.0  38.0        12.0
# 10    111   Karan         HR  Noida  47000.0  25.0         2.0
# 11    112    Amit    Finance   Pune  65000.0  36.0        10.0
# 12    113     NaN         IT  Delhi  53000.0   NaN         5.0
# 14    115   Pooja         HR  Noida      NaN  27.0         NaN
# 15    116   Vikas         IT  Delhi  80000.0  41.0        18.0
# 16    117   Nitin    Finance   Pune  58000.0  34.0         9.0
# ...

# %%
mask = df.City.isin(['Delhi' , 'Pune' , 'Noida'])
df[mask]
# Out:
#     EmpID     Name Department   City   Salary   Age  Experience
# 0     101      Ram         IT  Delhi  45000.0  24.0         2.0
# 1     102    Shyam         HR  Noida  52000.0  28.0         5.0
# 2     103    Mohan         IT  Delhi      NaN  30.0         7.0
# 4     105      Anu    Finance   Pune  70000.0  40.0        15.0
# 5     106     Riya         HR  Delhi  48000.0  27.0         4.0
# 6     107   Simran         IT  Noida  55000.0  26.0         3.0
# 7     108     Neha    Finance   Pune      NaN  31.0         NaN
# 9     110   Bhavna         IT  Delhi  62000.0  38.0        12.0
# 10    111    Karan         HR  Noida  47000.0  25.0         2.0
# 11    112     Amit    Finance   Pune  65000.0  36.0        10.0
# 12    113  Unknown         IT  Delhi  53000.0   NaN         5.0
# 14    115    Pooja         HR  Noida      NaN  27.0         NaN
# 15    116    Vikas         IT  Delhi  80000.0  41.0        18.0
# 16    117    Nitin    Finance   Pune  58000.0  34.0         9.0
# ...

# %%
#Display numeric columns only.
df.select_dtypes(include = np.number)
# Out:
#     EmpID   Salary   Age  Experience
# 0     101  45000.0  24.0         2.0
# 1     102  52000.0  28.0         5.0
# 2     103      NaN  30.0         7.0
# 3     104  38000.0   NaN         3.0
# 4     105  70000.0  40.0        15.0
# 5     106  48000.0  27.0         4.0
# 6     107  55000.0  26.0         3.0
# 7     108      NaN  31.0         NaN
# 8     109  41000.0  29.0         6.0
# 9     110  62000.0  38.0        12.0
# 10    111  47000.0  25.0         2.0
# 11    112  65000.0  36.0        10.0
# 12    113  53000.0   NaN         5.0
# 13    114  39000.0  33.0         8.0
# 14    115      NaN  27.0         NaN
# 15    116  80000.0  41.0        18.0
# 16    117  58000.0  34.0         9.0
# 17    118  51000.0  26.0         3.0
# 18    119  43000.0  32.0         7.0
# 19    120  60000.0   NaN        11.0

# %%
# Display string columns only.
df.select_dtypes(include = 'string')
df.columns.dtype=='str'
# Out:
# True

# %%
df.Name = df.Name.fillna('Unknown')

# %%
# Convert first 3 letters of Name using lambda.
df['Name'].map(lambda val : val[0:3])
# Out:
# 0     Ram
# 1     Shy
# 2     Moh
# 3     Roh
# 4     Anu
# 5     Riy
# 6     Sim
# 7     Neh
# 8     Moh
# 9     Bha
# 10    Kar
# 11    Ami
# 12    Unk
# 13    Sne
# 14    Poo
# 15    Vik
# 16    Nit
# 17    Ash
# 18    Rah
# 19    Pri
# Name: Name, dtype: str

# %%
df.Name.str[:3]
# Out:
# 0     Ram
# 1     Shy
# 2     Moh
# 3     Roh
# 4     Anu
# 5     Riy
# 6     Sim
# 7     Neh
# 8     Moh
# 9     Bha
# 10    Kar
# 11    Ami
# 12    Unk
# 13    Sne
# 14    Poo
# 15    Vik
# 16    Nit
# 17    Ash
# 18    Rah
# 19    Pri
# Name: Name, dtype: str

# %%
df['Name'].apply(lambda x : x[0:3])
# Out:
# 0     Ram
# 1     Shy
# 2     Moh
# 3     Roh
# 4     Anu
# 5     Riy
# 6     Sim
# 7     Neh
# 8     Moh
# 9     Bha
# 10    Kar
# 11    Ami
# 12    Unk
# 13    Sne
# 14    Poo
# 15    Vik
# 16    Nit
# 17    Ash
# 18    Rah
# 19    Pri
# Name: Name, dtype: str

# %%
convert = lambda val :[ n[0:3] for n in val]
convert(df.Name)
# Out:
# ['Ram',
#  'Shy',
#  'Moh',
#  'Roh',
#  'Anu',
#  'Riy',
#  'Sim',
#  'Neh',
#  'Moh',
#  'Bha',
#  'Kar',
#  'Ami',
#  'Unk',
#  'Sne',
#  'Poo',
#  'Vik',
#  'Nit',
#  'Ash',
#  'Rah',
#  'Pri']

# %%
convert = lambda val : (n[0:3] for n in val)
x= convert(df.Name)
for i in x:
    print(i)
# Out:
# Ram
# Shy
# Moh
# Roh
# Anu
# Riy
# Sim
# Neh
# Moh
# Bha
# Kar
# Ami
# Unk
# Sne
# Poo
# Vik
# Nit
# Ash
# Rah
# Pri

# %%
# 🔴 Advanced (25 Questions)
# Employee having maximum salary.
# Employee having minimum salary.
# Top 5 highest salary employees.
# Top 5 lowest salary employees.
# Create a copy.
# Remove all missing rows.
# Verify null values removed.
# Save cleaned data as CSV.
# Save cleaned data as Excel.
# Save cleaned data as JSON.
# Change EmpID as index.
# Reset index.
# Find correlation of numeric columns.
# Create pivot table:
# Index = Department
# Values = Salary
# Aggregation = Mean
# Create pivot table:
# Index = City
# Columns = Department
# Values = Salary
# Merge below bonus dataset with employee data.
# Plot department-wise employee count.
# Plot top 5 cities.
# Find duplicate names.
# Remove duplicate names.
# Number of employees in each city using value_counts().
# Find mode of Department.
# Display only float columns.
# Display only integer columns.
# Final cleaned dataframe.

# %%
# Employee having maximum salary.
df[df.Salary == df.Salary.max()]
# Out:
#     EmpID   Name Department   City   Salary   Age  Experience
# 15    116  Vikas         IT  Delhi  80000.0  41.0        18.0

# %%
# Employee having minimum salary.
df[df.Salary == df.Salary.min()]
# Out:
#    EmpID   Name Department    City   Salary  Age  Experience
# 3    104  Rohan      Sales  Mumbai  38000.0  NaN         3.0

# %%
# Top 5 highest salary employees.
df.sort_values(by = 'Salary' , ascending = False).head(5)
# Out:
#     EmpID    Name Department   City   Salary   Age  Experience
# 15    116   Vikas         IT  Delhi  80000.0  41.0        18.0
# 4     105     Anu    Finance   Pune  70000.0  40.0        15.0
# 11    112    Amit    Finance   Pune  65000.0  36.0        10.0
# 9     110  Bhavna         IT  Delhi  62000.0  38.0        12.0
# 19    120   Priya         IT  Noida  60000.0   NaN        11.0

# %%
# Top 5 lowest salary employees.
df.sort_values(by = 'Salary').head(5)
# Out:
#     EmpID   Name Department    City   Salary   Age  Experience
# 3     104  Rohan      Sales  Mumbai  38000.0   NaN         3.0
# 13    114  Sneha      Sales  Mumbai  39000.0  33.0         8.0
# 8     109  Mohit      Sales  Mumbai  41000.0  29.0         6.0
# 18    119  Rahul      Sales  Mumbai  43000.0  32.0         7.0
# 0     101    Ram         IT   Delhi  45000.0  24.0         2.0

# %%
# Create a copy.
newdf = df.copy()

# %%
# Verify null values removed.
newdf.isnull().sum()
# Out:
# EmpID         0
# Name          0
# Department    0
# City          0
# Salary        3
# Age           3
# Experience    2
# dtype: int64

# %%
# Save cleaned data as csv.
newdf.to_csv('test.csv')

# %%
# Save cleaned data as Excel.
newdf.to_excel('test.xlsx')

# %%
# Save cleaned data as json.
newdf.to_json('test.json')

# %%
# Change EmpID as index.
newdf=newdf.rename(columns = {'EmpID': 'index'})

# %%
# reset_index
newdf.reset_index(drop=True)
# Out:
#     index     Name Department    City   Salary   Age  Experience
# 0     101      Ram         IT   Delhi  45000.0  24.0         2.0
# 1     102    Shyam         HR   Noida  52000.0  28.0         5.0
# 2     103    Mohan         IT   Delhi      NaN  30.0         7.0
# 3     104    Rohan      Sales  Mumbai  38000.0   NaN         3.0
# 4     105      Anu    Finance    Pune  70000.0  40.0        15.0
# 5     106     Riya         HR   Delhi  48000.0  27.0         4.0
# 6     107   Simran         IT   Noida  55000.0  26.0         3.0
# 7     108     Neha    Finance    Pune      NaN  31.0         NaN
# 8     109    Mohit      Sales  Mumbai  41000.0  29.0         6.0
# 9     110   Bhavna         IT   Delhi  62000.0  38.0        12.0
# 10    111    Karan         HR   Noida  47000.0  25.0         2.0
# 11    112     Amit    Finance    Pune  65000.0  36.0        10.0
# 12    113  Unknown         IT   Delhi  53000.0   NaN         5.0
# ...

# %%
# Find correlation of numeric columns.
df.corr(numeric_only=True)
# Out:
#                EmpID    Salary       Age  Experience
# EmpID       1.000000  0.206784  0.255244    0.326504
# Salary      0.206784  1.000000  0.739998    0.802900
# Age         0.255244  0.739998  1.000000    0.980018
# Experience  0.326504  0.802900  0.980018    1.000000

# %%
bonus = {
"EmpID":[101,102,103,104,105,106,107,108,109,110],
"Bonus":[5000,7000,3000,2000,10000,4500,6000,9000,2500,8500]
}
bonus_df = pd.DataFrame(bonus)

# %%
# Merge below bonus dataset with employee data.
# df.merge(bonus_df,on='EmpID')
# bonus_df.merge(newdf , left_on = 'EmpID' ,right_on='index')
newdf.merge(bonus_df , left_on = 'index' ,right_on='EmpID')
# Out:
#    index    Name Department    City   Salary   Age  Experience  EmpID  Bonus
# 0    101     Ram         IT   Delhi  45000.0  24.0         2.0    101   5000
# 1    102   Shyam         HR   Noida  52000.0  28.0         5.0    102   7000
# 2    103   Mohan         IT   Delhi      NaN  30.0         7.0    103   3000
# 3    104   Rohan      Sales  Mumbai  38000.0   NaN         3.0    104   2000
# 4    105     Anu    Finance    Pune  70000.0  40.0        15.0    105  10000
# 5    106    Riya         HR   Delhi  48000.0  27.0         4.0    106   4500
# 6    107  Simran         IT   Noida  55000.0  26.0         3.0    107   6000
# 7    108    Neha    Finance    Pune      NaN  31.0         NaN    108   9000
# 8    109   Mohit      Sales  Mumbai  41000.0  29.0         6.0    109   2500
# 9    110  Bhavna         IT   Delhi  62000.0  38.0        12.0    110   8500

# %%
# Plot department-wise employee count.
df['Department'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Department'>

# %%
# Plot top 5 cities.
df.City.value_counts().head().plot(kind = 'bar')
# Out:
# <Axes: xlabel='City'>

# %%
# Display only float columns.
df.select_dtypes(include = float)
# Out:
#      Salary   Age  Experience
# 0   45000.0  24.0         2.0
# 1   52000.0  28.0         5.0
# 2       NaN  30.0         7.0
# 3   38000.0   NaN         3.0
# 4   70000.0  40.0        15.0
# 5   48000.0  27.0         4.0
# 6   55000.0  26.0         3.0
# 7       NaN  31.0         NaN
# 8   41000.0  29.0         6.0
# 9   62000.0  38.0        12.0
# 10  47000.0  25.0         2.0
# 11  65000.0  36.0        10.0
# 12  53000.0   NaN         5.0
# 13  39000.0  33.0         8.0
# 14      NaN  27.0         NaN
# 15  80000.0  41.0        18.0
# 16  58000.0  34.0         9.0
# 17  51000.0  26.0         3.0
# 18  43000.0  32.0         7.0
# 19  60000.0   NaN        11.0

# %%
# Display only integer columns.
df.select_dtypes(include = int)
# Out:
#     EmpID
# 0     101
# 1     102
# 2     103
# 3     104
# 4     105
# 5     106
# 6     107
# 7     108
# 8     109
# 9     110
# 10    111
# 11    112
# 12    113
# 13    114
# 14    115
# 15    116
# 16    117
# 17    118
# 18    119
# 19    120

# %%
# #Remove all missing rows.
df.dropna()
# Out:
#     EmpID    Name Department    City   Salary   Age  Experience
# 0     101     Ram         IT   Delhi  45000.0  24.0         2.0
# 1     102   Shyam         HR   Noida  52000.0  28.0         5.0
# 4     105     Anu    Finance    Pune  70000.0  40.0        15.0
# 5     106    Riya         HR   Delhi  48000.0  27.0         4.0
# 6     107  Simran         IT   Noida  55000.0  26.0         3.0
# 8     109   Mohit      Sales  Mumbai  41000.0  29.0         6.0
# 9     110  Bhavna         IT   Delhi  62000.0  38.0        12.0
# 10    111   Karan         HR   Noida  47000.0  25.0         2.0
# 11    112    Amit    Finance    Pune  65000.0  36.0        10.0
# 13    114   Sneha      Sales  Mumbai  39000.0  33.0         8.0
# 15    116   Vikas         IT   Delhi  80000.0  41.0        18.0
# 16    117   Nitin    Finance    Pune  58000.0  34.0         9.0
# 17    118    Asha         HR   Delhi  51000.0  26.0         3.0
# 18    119   Rahul      Sales  Mumbai  43000.0  32.0         7.0

# %%
# #Create pivot table:
    # Index = Department
    # Values = Salary
    # Aggregation = Mean
df.pivot_table(
    index='Department',
    values= ['Salary' , 'Experience'],
    aggfunc = 'mean'
)
# Out:
#             Experience        Salary
# Department
# Finance      11.333333  64333.333333
# HR            3.500000  49500.000000
# IT            8.285714  59166.666667
# Sales         6.000000  40250.000000

# %%
# Find duplicate names.
df[df.duplicated(subset = 'Name')]
# Out:
# Empty DataFrame
# Columns: [EmpID, Name, Department, City, Salary, Age, Experience]
# Index: []
