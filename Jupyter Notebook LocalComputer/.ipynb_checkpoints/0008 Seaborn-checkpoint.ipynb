# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('titanic')

# %%
df.shape
# Out:
# (891, 15)

# %%
plt.figure(figsize = (12,3))
sns.heatmap(df.isnull())
plt.show()

# %%
df.deck.unique()
# Out:
# [NaN, 'C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, str): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
df.age.isnull().sum()/df.shape[0]*100
# Out:
# np.float64(19.865319865319865)

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
df = df.drop(columns = ['deck' , 'pclass' , 'embarked' , 'who' , 'adult_male'  , 'alone' ])

# %%
df.shape
# Out:
# (891, 9)

# %%
df.head(2)
# Out:
#    survived     sex   age  sibsp  parch     fare  class  embark_town alive
# 0         0    male  22.0      1      0   7.2500  Third  Southampton    no
# 1         1  female  38.0      1      0  71.2833  First    Cherbourg   yes

# %%
plt.figure(figsize = (12,3))
sns.heatmap(df.isnull())
plt.show()

# %%
df = df.ffill()

# %%
df.isnull().sum()
# Out:
# survived       0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# class          0
# embark_town    0
# alive          0
# dtype: int64

# %%
plt.figure(figsize= (8,3))
sns.countplot(x = 'alive' , hue = 'sex' , data =df   )
plt.show()

# %%
plt.figure(figsize = (8,3))
sns.countplot(x = 'alive' , hue = 'class' , data=df)
plt.show()

# %%
plt.figure(figsize = (8,3))
sns.histplot(x = 'age' , data=df)
plt.show()

# %%
plt.figure(figsize = (8,3))
sns.histplot(x = 'age' , data=df , kde = True)
plt.show()

# %%
plt.figure(figsize = (15,3))
sns.countplot(x = 'alive' , hue = 'age' , data=df)
plt.show()

# %%
plt.figure(figsize = (8,3))
sns.histplot(x = 'age' , hue = 'alive', data=df)
plt.show()

# %%
plt.figure(figsize = (8,3))
sns.histplot(x = 'age' , hue = 'alive', data=df , kde = True)
plt.show()

# %%
df.head(2)
# Out:
#    survived     sex   age  sibsp  parch     fare  class  embark_town alive
# 0         0    male  22.0      1      0   7.2500  Third  Southampton    no
# 1         1  female  38.0      1      0  71.2833  First    Cherbourg   yes

# %%
plt.figure(figsize = (12,3))
sns.histplot(x = 'fare' , data = df , kde = True)
plt.show()

# %%
plt.figure(figsize = (12,4))
sns.boxplot(x = 'fare' , data = df )
plt.show()

# %%
plt.figure(figsize = (12,4))
sns.boxplot(x = 'fare' , data = df , hue = 'alive')
plt.show()

# %%
plt.figure(figsize = (12,4))
sns.boxplot(x = 'fare' , data = df[df['fare']<500] , hue = 'alive')
plt.show()

# %%
plt.figure(figsize = (12,4))
sns.histplot(x = 'fare' , data = df[df['fare']<500] , hue = 'alive' , kde = True)
plt.show()

# %%
plt.figure(figsize = (12,4))
sns.histplot(x = 'fare' , data = df , hue = 'alive' , kde = True)
plt.show()

# %%
plt.figure(figsize = (8,3))
sns.countplot(x = 'alive' , data=df )
plt.show()

# %%
plt.figure(figsize = (8,3))
sns.countplot(x = 'alive' , data=df , hue = 'sex')
plt.show()

# %%
plt.figure(figsize = (8,3))
sns.violinplot(x = 'alive' , data=df , hue = 'sex')
plt.show()

# %%
plt.figure(figsize = (8,3))
sns.swarmplot(x = 'alive' , data=df , hue = 'sex')
plt.show()
# Out:
# C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages\seaborn\categorical.py:3399: UserWarning: 48.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages\seaborn\categorical.py:3399: UserWarning: 94.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize = (8,3))
sns.stripplot(x = 'alive' , data=df , hue = 'sex')
plt.show()
